# %%
Num = int(input("Enter a number:"))
if Num % 2 == 0:
      print ("You enter a even number")

else:

      print("You enter an odd number")
# Out:
# Enter a number: 3
# You enter an odd number

# %%
A = int(input("Enter your first number:"))
B = int(input("Enter your second number:"))
print("Sum of your two numbers is:", A + B)
# Out:
# Enter your first number: 2
# Enter your second number: 6
# Sum of your two numbers is: 8

# %%
A = int(input("Enter your first number:"))
B = int(input("Enter your second number:"))
C = int(input("Enter your third number:"))
if A>=B and A>=C:
    print("Biggest or Maximum number is:",A)
elif B>=A and B>=C:
    print("Biggest or Maximum number is:",B)
else:
    print("Biggest or Maximum number is:",C)
# Out:
# Enter your first number: 4
# Enter your second number: 3
# Enter your third number: 1
# Biggest or Maximum number is: 4

# %%
Celsius = float(input("Enter temperature in Celsius: "))
Fahrenheit = (Celsius * 9/5) + 32
print("Temperature in Fahrenheit is:", Fahrenheit)
# Out:
# Enter temperature in Celsius:  30
# Temperature in Fahrenheit is: 86.0

# %%
Num = int(input("Enter a number:"))
if Num>= 0:
      print ("You enter a positive number")

else:
      print("You enter negative number")
# Out:
# Enter a number: 4
# You enter a positive number
