# %%
print ("Hello IQRA")
# Out:
# Hello IQRA

# %%
print ("How are you?")
# Out:
# How are you?

# %%
Name = "IQRA EIMAN"
Age = 18
print (Name)
print (Age)
# Out:
# IQRA EIMAN
# 18

# %%
print ("My Name is ",Name)
print ("My Age is ",Age)
# Out:
# My Name is  IQRA EIMAN
# My Age is  18

# %%
name = input("What is your name?")
print("Hy", name)
# Out:
# What is your name? IQRA EIMAN
# Hy IQRA EIMAN

# %%
Old_age = input("Enter your Old age:")
New_age = int(Old_age)+2
print("Your New age is:",New_age)
# Out:
# Enter your Old age: 16
# Your New age is: 18
